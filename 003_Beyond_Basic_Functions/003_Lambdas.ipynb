# %%
# Sorting
scientists = ['Albert Einstein', 'Marie Curie', 'Niels Bohr', 'Issac Newton', 'Carl Linnaeus']

# %%
sorted(scientists, key=lambda x: x.split()[-1])
# Out:
# ['Niels Bohr',
#  'Marie Curie',
#  'Albert Einstein',
#  'Carl Linnaeus',
#  'Issac Newton']

# %%
from IPython.display import Image
Image('lamda_diff.jpg')
